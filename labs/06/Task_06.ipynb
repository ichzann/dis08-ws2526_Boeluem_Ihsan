# %%
import re
import pandas as pd


csv_path_contacts = "/Users/ihsanbolum/dis08-ws2526_Boeluem_Ihsan/labs/06/csv/contacts.csv"
csv_path_orders = "/Users/ihsanbolum/dis08-ws2526_Boeluem_Ihsan/labs/06/csv/orders.csv"

csv_contacts = pd.read_csv(csv_path_contacts)
csv_contacts.head()
# Out:
#               name                     address  \
# 0         Uma Rios      413-2451 Lobortis, Rd.
# 1     Herman Patel             2877 Nec Avenue
# 2      Fritz Mckee  Ap #350-8665 Ultricies Av.
# 3  Robert Melendez         Ap #988-4035 Mi St.
# 4   Calista Carter     Ap #891-4549 Massa. St.
#
#                                 email           phone
# 0               augue.ac@hotmail.couk  (836) 811-6616
# 1  adipiscing.lacus.ut@protonmail.net  (221) 605-4530
# 2       placerat.velit@protonmail.com  (424) 937-3765
# 3            sodales.elit@outlook.com  (751) 973-6476
# 4         tristique.neque@hotmail.org  (235) 444-8645

# %%
#Extract all email addresses from the text.
df = pd.DataFrame(csv_contacts)
df["email"]
# Out:
# 0                   augue.ac@hotmail.couk
# 1      adipiscing.lacus.ut@protonmail.net
# 2           placerat.velit@protonmail.com
# 3                sodales.elit@outlook.com
# 4             tristique.neque@hotmail.org
#                      ...
# 95                    ultricies@yahoo.com
# 96                    aliquam@hotmail.org
# 97                  sed.pede.nec@aol.couk
# 98    varius.nam.porttitor@protonmail.edu
# 99                      leo.morbi@aol.com
# Name: email, Length: 100, dtype: object

# %%
#Extract all phone numbers from the text.
df["phone"]
# Out:
# 0     (836) 811-6616
# 1     (221) 605-4530
# 2     (424) 937-3765
# 3     (751) 973-6476
# 4     (235) 444-8645
#            ...
# 95    (108) 368-3267
# 96    1-455-448-1775
# 97    (273) 843-5131
# 98    (572) 547-5575
# 99    (433) 308-6684
# Name: phone, Length: 100, dtype: object

# %%
#Extract all names that start with the letter ‘J’.

df.loc[df["name"].str.match(r"^J"), "name"]
# Out:
# 8        James Monroe
# 25       John O'Neill
# 33    Jameson Wallace
# 51      Jamal Parsons
# 67       Judah Branch
# 80        Jaquelyn Le
# 93      Jenna Herrera
# Name: name, dtype: object

# %%
#Extract all street names that contain the word 'St'.
df.loc[df["address"].str.match(r".*St.*")]
# Out:
#                 name                             address  \
# 3    Robert Melendez                 Ap #988-4035 Mi St.
# 4     Calista Carter             Ap #891-4549 Massa. St.
# 5      Maris Patrick                   799-5917 Erat St.
# 7        Grant Hodge                  5182 Penatibus St.
# 10  Sandra O'donnell    Ap #271-6656 Sollicitudin Street
# 20         Dora Diaz                   6564 Proin Street
# 21      Latifah Reed             Ap #397-8170 Libero St.
# 22     Kaye Mitchell                    915-3764 Est St.
# 29      Harrison Day       P.O. Box 462, 1623 Nec Street
# 31       Bryar Parks        P.O. Box 113, 6239 Augue St.
# 33   Jameson Wallace  P.O. Box 101, 7533 Senectus Street
# 35        Debra Wise           Ap #715-6617 Dolor Street
# 38     Noelani Oneil               106-627 Consequat St.
# 39      Bruce Mooney         Ap #373-3604 Mollis. Street
# 40    Brielle Castro                  669-6549 Morbi St.
# 42       Lionel Reid          Ap #639-6437 Dolor. Street
# 44    Brielle Herman                    2537 Ornare, St.
# 49  Ferris Cervantes            Ap #697-9528 Aliquet St.
# 58   Carlos Thornton           227-1473 Porttitor Street
# 59     Kevin Serrano                 408-7191 Nec Street
# 60     Galvin Daniel               Ap #961-2908 Erat St.
# 62     Scott Hartman         P.O. Box 245, 7116 Amet St.
# 64      Reece Rivers                     120-5863 At St.
# 72      Dawn Rodgers      P.O. Box 283, 4695 Aliquam St.
# 74     Norman Waller                   7360 Neque Street
# 75    Latifah Booker                360-8053 Dapibus St.
# 80       Jaquelyn Le         Ap #506-313 Egestas, Street
# 85       Baker Avery                Ap #146-8548 Sed St.
# 87        Mia Kinney       P.O. Box 450, 9508 Risus. St.
# 88       Hyatt Drake                    9709 Quisque St.
# 90    Aileen Cochran             Ap #806-7090 Massa. St.
# 91      Clare Hansen             Ap #987-1774 Non Street
#
#                                     email           phone
# 3                sodales.elit@outlook.com  (751) 973-6476
# 4             tristique.neque@hotmail.org  (235) 444-8645
# 5                      purus.in@yahoo.net  1-216-210-2453
# 7                    placerat@hotmail.net  1-668-811-3565
# 10              sem.mollis@protonmail.edu  (633) 561-2222
# 20        maecenas.libero.est@google.couk  1-445-247-4964
# 21              metus.in.lorem@outlook.ca  1-832-643-6786
# 22              nullam.velit.dui@aol.couk  (430) 249-1364
# 29     nulla.integer.vulputate@icloud.edu  (873) 788-9710
# 31              mauris.non@protonmail.net  1-648-738-4794
# 33                      dui.nec@yahoo.net  1-152-482-1963
# 35               vel.nisl.quisque@aol.edu  (811) 308-2587
# 38                ipsum.dolor.sit@aol.org  (710) 187-2256
# 39                     nostra.per@aol.com  (675) 372-1176
# 40                      ac.ipsum@yahoo.ca  (740) 362-4105
# 42                  et.rutrum@icloud.couk  (678) 955-5583
# 44               ipsum.primis@hotmail.org  1-614-767-1851
# 49                  malesuada@outlook.com  1-236-479-3538
# 58       sagittis.placerat.cras@yahoo.com  1-127-824-4671
# 59  aliquam.adipiscing.lobortis@google.ca  (553) 534-2804
# 60                     nullam@outlook.net  1-485-516-7822
# 62         commodo.hendrerit@hotmail.couk  (836) 763-3572
# 64                      aenean@google.edu  (841) 768-0531
# 72                      semper@icloud.org  1-638-850-8809
# 74           senectus.et.netus@icloud.com  1-452-216-8119
# 75    cubilia.curae.phasellus@hotmail.net  1-615-465-5506
# 80          felis.purus.ac@protonmail.net  (227) 715-5459
# 85              volutpat.nulla@google.net  (956) 351-3724
# 87             etiam.bibendum@hotmail.com  1-869-798-0813
# 88                         odio@yahoo.edu  1-868-331-1980
# 90                      sed.nunc@aol.couk  1-301-323-0477
# 91                  dui.augue@outlook.org  1-788-814-5232

# %%
#Extract the last names of all people.
df["name"].str.extract(r"\s+(\S+)")
# Out:
#             0
# 0         Uma
# 1      Herman
# 2       Fritz
# 3      Robert
# 4     Calista
# ..        ...
# 95    Barrett
# 96  Britanney
# 97     Haviva
# 98    Latifah
# 99     Connor
#
# [100 rows x 1 columns]

# %%
#Extract all email domains (part after the @ sign).
df["email"].str.extract(r"@(\S+)")
# Out:
#                  0
# 0     hotmail.couk
# 1   protonmail.net
# 2   protonmail.com
# 3      outlook.com
# 4      hotmail.org
# ..             ...
# 95       yahoo.com
# 96     hotmail.org
# 97        aol.couk
# 98  protonmail.edu
# 99         aol.com
#
# [100 rows x 1 columns]

# %%
#Find all entries where the phone number ends with ‘7’.
df[df["phone"].str.endswith(r"7")]
# Out:
#                 name                      address  \
# 26   Hamilton Palmer  P.O. Box 250, 9100 Nunc Rd.
# 35        Debra Wise    Ap #715-6617 Dolor Street
# 53       Reed Wilder        Ap #486-9308 At, Road
# 56     Ashely Morgan           797-3522 Fames Rd.
# 77       Ivory Cantu   Ap #512-8744 Lectus Avenue
# 90    Aileen Cochran      Ap #806-7090 Massa. St.
# 95  Barrett Mcfadden                  3445 Et Rd.
#
#                              email           phone
# 26            massa.non@google.net  (746) 275-2337
# 35        vel.nisl.quisque@aol.edu  (811) 308-2587
# 53      cursus.integer@hotmail.com  (696) 773-5037
# 56         lobortis.class@yahoo.ca  (343) 698-0617
# 77  aliquet.molestie@protonmail.ca  (366) 231-7987
# 90               sed.nunc@aol.couk  1-301-323-0477
# 95             ultricies@yahoo.com  (108) 368-3267

# %%
#Extract all instances of first names that end with the letter 'e'.
df["vorname"] = df["name"].str.extract(r"(\S+)\s+")

df[df["vorname"].str.endswith(r"e")]
# Out:
#               name                             address  \
# 11   Vance Sellers           771-1102 Sollicitudin Rd.
# 14    Reese Newman             987-6959 Interdum. Road
# 22   Kaye Mitchell                    915-3764 Est St.
# 39    Bruce Mooney         Ap #373-3604 Mollis. Street
# 40  Brielle Castro                  669-6549 Morbi St.
# 44  Brielle Herman                    2537 Ornare, St.
# 48      Kylie Levy              Ap #374-4908 Quam, Ave
# 64    Reece Rivers                     120-5863 At St.
# 65       Bree Owen               Ap #176-5922 Enim Rd.
# 84   Cade Bradshaw  P.O. Box 299, 9353 Aliquet. Avenue
# 91    Clare Hansen             Ap #987-1774 Non Street
#
#                              email           phone  vorname
# 11     dui.fusce.diam@hotmail.couk  1-946-737-5281    Vance
# 14               dictum.eu@aol.edu  (573) 457-2876    Reese
# 22       nullam.velit.dui@aol.couk  (430) 249-1364     Kaye
# 39              nostra.per@aol.com  (675) 372-1176    Bruce
# 40               ac.ipsum@yahoo.ca  (740) 362-4105  Brielle
# 44        ipsum.primis@hotmail.org  1-614-767-1851  Brielle
# 48  pellentesque.massa@outlook.com  (387) 415-4632    Kylie
# 64               aenean@google.edu  (841) 768-0531    Reece
# 65        leo.vivamus.nibh@aol.org  (638) 185-3708     Bree
# 84         aliquet.odio@yahoo.couk  (448) 542-7818     Cade
# 91           dui.augue@outlook.org  1-788-814-5232    Clare
